# %% [markdown]
# <a href="https://colab.research.google.com/github/Ferreira-Jefferson/meuPO/blob/main/meuPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
from google.colab import userdata

import google.generativeai as genai

import textwrap
from IPython.display import display
from IPython.display import Markdown

from google.colab import files

import numpy as np
import pandas as pd

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
def to_markdown(text):
  text = text.replace('•', '*')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
def save_history(history):
  pass

# %%
def list_gemini_models():
  for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
      print(m.name)
list_gemini_models()
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
documents = [
        {
      "title": "introdução",
      "content": '''
          Olá sou o Seu P.O e irei de ajudar com todas algumas atividades que o P.O é responsável.

          Veja abaixo os processos que em que irei te ajudar.

          Comandos importantes:
            CHAT: Inicia um chat para tirar dúvidas que eu como Seu P.O estou capacitado para responder.
            SALVAR: Quando eu encerrar uma etapa do processo irei te perguntar se deseja salvar o resultado no Google Docs

      '''
    },
    {
      "title": "Menu de opções,  que é possível fazer",
      "content": '''
          Processos:
            Criar documento de Visão do Produto
            Fazer o Levantamento de Requisitos
            Histórias de Usuários
            Histórias de Usuários Priorizadas
            Backlog do Produto
            Lista de Itens do Backlog
            Detalhar Tarefas do Backlog
            Criar testes das tarefas do backlog
      '''
    },
    {
        "title": "Criar documento de Visão do Produto",
        "content": "Criar documento de Visão do Produto"
    },
    {
        "title": "Fazer o Levantamento de Requisitos",
        "content": "Fazer o Levantamento de Requisitos"
    },
    {
        "title": "Histórias de Usuários",
        "content": "Histórias de Usuários"
    },
    {
        "title": "Histórias de Usuários Priorizadas",
        "content": "Histórias de Usuários Priorizadas"
    },
    {
        "title": "Backlog do Produto",
        "content": "Backlog do Produto"
    },
    {
        "title": "Lista de Itens do Backlog",
        "content": "Lista de Itens do Backlog"
    },
    {
        "title": "Detalhar Tarefas do Backlog",
        "content": "Detalhar Tarefas do Backlog"
    },
    {
        "title": "Outros. Perguntas fora do tema ou contexto",
        "content": "Desculpe sou um P.O, não consigo te auxiliar nisso."
    }
]

# %%
df = pd.DataFrame(documents)
df.columns = ['Title', 'Text']
df
# Out:
#                                         Title  \
# 0       Menu de opções,  que é possível fazer
# 1         Criar documento de Visão do Produto
# 2          Fazer o Levantamento de Requisitos
# 3                       Histórias de Usuários
# 4           Histórias de Usuários Priorizadas
# 5                          Backlog do Produto
# 6                   Lista de Itens do Backlog
# 7                 Detalhar Tarefas do Backlog
# 8  Outros. Perguntas fora do tema ou contexto
#
#                                                 Text
# 0  \n          Menu:\n            Criar documento...
# 1                Criar documento de Visão do Produto
# 2                 Fazer o Levantamento de Requisitos
# 3                              Histórias de Usuários
# 4                  Histórias de Usuários Priorizadas
# 5                                 Backlog do Produto
# 6                          Lista de Itens do Backlog
# 7                        Detalhar Tarefas do Backlog
# ...

# %%
model = 'models/embedding-001'

# Get the embeddings of each text and add to an embeddings column in the dataframe
def embed_fn(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             task_type="retrieval_document",
                             title=title)["embedding"]

df['Embeddings'] = df.apply(lambda row: embed_fn(row['Title'], row['Text']), axis=1)
df
# Out:
#                                         Title  \
# 0       Menu de opções,  que é possível fazer
# 1         Criar documento de Visão do Produto
# 2          Fazer o Levantamento de Requisitos
# 3                       Histórias de Usuários
# 4           Histórias de Usuários Priorizadas
# 5                          Backlog do Produto
# 6                   Lista de Itens do Backlog
# 7                 Detalhar Tarefas do Backlog
# 8  Outros. Perguntas fora do tema ou contexto
#
#                                                 Text  \
# 0  \n          Menu:\n            Criar documento...
# 1                Criar documento de Visão do Produto
# 2                 Fazer o Levantamento de Requisitos
# 3                              Histórias de Usuários
# 4                  Histórias de Usuários Priorizadas
# 5                                 Backlog do Produto
# 6                          Lista de Itens do Backlog
# 7                        Detalhar Tarefas do Backlog
# ...

# %%
query = "O que é uma tarefa?"

request = genai.embed_content(model=model,
                              content=query,
                              task_type="retrieval_query")

# %%
def find_best_passage(query, dataframe):
  query_embedding = genai.embed_content(model=model,
                                        content=query,
                                        task_type="retrieval_query")
  dot_products = np.dot(np.stack(dataframe['Embeddings']), query_embedding["embedding"])
  idx = np.argmax(dot_products)
  return dataframe.iloc[idx]['Text']

# %%
passage = find_best_passage(query, df)
passage
# Out:
# 'Detalhar Tarefas do Backlog'

# %%
def chat_gemini(old_history = []):
  gemini_model = 'gemini-1.5-pro-latest'
  system_instruction='''
  Você é um product owner e só deve responder perguntas relacionadas a este escopo.
  '''
  model = genai.GenerativeModel(model_name=gemini_model, system_instruction=system_instruction)
  chat = model.start_chat(history=old_history)
  while True:
      texto = input("You: ")
      if texto.lower() in ["sair", "encerrar", "parar"]: break
      response = chat.send_message(texto)
      print(response.text, end='\n')

  save_current_history = input("Salvar Histórico do Chat? [Y, N, S, Sim, Não]: ").strip().upper()
  if save_current_history in ['Y', 'N', 'S', 'SIM', 'NÃO', 'NAO']:
    save_history(chat.history)

# %%
chat_gemini()

# %%
def subir_arquivo_local():
  uploaded = files.upload()

  for fn in uploaded.keys():
    print('Arquivo "{name}" com tamanho de {length} bytes, totalmente carregado!'.format(
        name=fn, length=len(uploaded[fn])))
  print(uploaded)

def subir_arquivo_via_google_drive():
  from google.colab import drive
  drive.mount('/content/drive')
  guia = '''### Agora que o Google Drive está conectado siga os seguintes passos para escolher o arquivo.
    * Clique no ícone pasta "🗀" na lateral esquerda do google colab
    * Clique na pasta "drive"
    * Na pasta "MyDrive" encontre o arquivo desejado
    * Posicione o mouse acima do arquivo desejado
    * Clique em "⋮" no canto direito do arquivo
    * Clique em "Copiar caminho"
    * Cole o caminho no input abaixo'''

  display(to_markdown(guia))

# %%
def myPO():
  # Selecionar arquivo para análise
  display(to_markdown("## **Seja bem vindo ao MyPO**"))
  display(to_markdown("### **# Iniciar com arquivo gerado pelo MyPO?**"))


myPO()

# %%
# Imports for JupyterLite
# %pip install -q ipywidgets

# %%
import ipywidgets as widgets

# %%
v.Select(append_icon='mdi-gamepad-down', label='Fruits')
# Out:
# Select(append_icon='mdi-gamepad-down', label='Fruits', layout=None)
